# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn.datasets import make_classification, make_moons, make_circles

# for splitting arrays into test & train subset
from sklearn.model_selection import train_test_split

# for accuracy score of classification
from sklearn.metrics import accuracy_score

# %%
# All activation functions

def relu(x):
    return np.maximum(0, x)
    
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def reluDerivative(x):
    return (x > 0).astype(float)

def sigmoidDerivative(x):
    return sigmoid(x) * (1 - sigmoid(x))

# %%
# without hidden layers

def trainNoHidden(X, y, lr = 0.01, epochs = 1000):
    np.random.seed(42)
    weights = np.random.randn(X.shape[1], 1)
    bias = np.zeros((1,))

    print("With No Hidden Layer")
    for epoch in range(epochs):
        # Forward Pass
        z = np.dot(X, weights) + bias
        predictions = sigmoid(z).flatten()

        # Binary Cross entropy loss function
        loss = -np.mean(y * np.log(predictions + 1e-8) + (1 - y) * np.log(1 - predictions + 1e-8))

        # Backward Pass
        errors = predictions - y
        grad_weights = np.dot(X.T, errors.reshape(-1, 1)) / X.shape[0]
        grad_bias = np.mean(errors)

        # Updating weights
        weights -= lr * grad_weights
        bias -= lr * grad_bias

        if epoch % 100 == 0 or epoch == epochs - 1:
            print(f"Epoch {epoch}, Training Loss: {loss:.4f}")

    return weights, bias

# %%
# with 1 hidden layer
def trainWithHidden(X, y, hidden_neurons = 10, lr = 0.01, epochs = 1000, activation = "relu"):
    np.random.seed(42)
    input_neurons = X.shape[1]
    output_neurons = 1

    # Initialize Weights
    W1 = np.random.randn(input_neurons, hidden_neurons) * 0.1
    b1 = np.zeros((hidden_neurons,))
    W2 = np.random.randn(hidden_neurons, output_neurons) * 0.1
    b2 = np.zeros((output_neurons,))

    # Choose Activation Function
    act_fn = relu if activation == "relu" else sigmoid
    act_fn_derivative = reluDerivative if activation == "relu" else sigmoidDerivative

    print("\nHidden Layer")
    for epoch in range(epochs):
        # Forward Pass
        Z1 = np.dot(X, W1) + b1
        A1 = act_fn(Z1)
        Z2 = np.dot(A1, W2) + b2
        predictions = sigmoid(Z2).flatten()

        # Loss (Binary Cross-Entropy)
        loss = -np.mean(y * np.log(predictions + 1e-8) + (1 - y) * np.log(1 - predictions + 1e-8))

        # Backward Pass
        errors = predictions - y
        dZ2 = errors.reshape(-1, 1)
        dW2 = np.dot(A1.T, dZ2) / X.shape[0]
        db2 = np.mean(dZ2, axis=0)

        dA1 = np.dot(dZ2, W2.T)
        dZ1 = dA1 * act_fn_derivative(Z1)
        dW1 = np.dot(X.T, dZ1) / X.shape[0]
        db1 = np.mean(dZ1, axis=0)

        # Update Weights
        W2 -= lr * dW2
        b2 -= lr * db2
        W1 -= lr * dW1
        b1 -= lr * db1

        if epoch % 100 == 0 or epoch == epochs - 1:
            predictions_binary = (predictions > 0.5).astype(int)
            accuracy = accuracy_score(y, predictions_binary)
            print(f"Epoch {epoch}, Training Loss: {loss:.4f}, Accuracy: {accuracy:.4f}")

    return W1, b1, W2, b2

# %%
# prediction function

def predict(X, weights, bias):
    z = np.dot(X, weights) + bias
    
    return (sigmoid(z) > 0.5).astype(int).flatten()

def predictWithHidden(X, W1, b1, W2, b2, activation="relu"):
    act_fn = relu if activation == "relu" else sigmoid
    A1 = act_fn(np.dot(X, W1) + b1)
    predictions = sigmoid(np.dot(A1, W2) + b2)
    
    return (predictions > 0.5).astype(int).flatten()

# %%
linearly_separable_data = make_classification(n_samples=1000, n_features=2, n_informative=2, 
                           n_redundant=0, n_clusters_per_class=1, 
                           class_sep=2.0, flip_y=0.0, weights=[0.5, 0.5], 
                           random_state=42)


non_linear_moons = make_moons(n_samples = 1000, noise = 0.1, random_state = 42)
non_linear_circles = make_circles(n_samples = 1000, noise = 0.1, factor = 0.5, random_state = 42)

# %%
datasets = {"Linear": linearly_separable_data, "Moons": non_linear_moons, "Circles": non_linear_circles}

# %%
for name, data in datasets.items():
    X, y = data
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

    # Without Hidden Layer
    weights, bias = trainNoHidden(X_train, y_train, lr = 0.1, epochs = 1000)
    y_pred_no_hidden = predict(X_test, weights, bias)
    acc_no_hidden = accuracy_score(y_test, y_pred_no_hidden)

    # With Hidden Layer
    W1, b1, W2, b2 = trainWithHidden(X_train, y_train, hidden_neurons = 10, lr = 0.1, epochs = 4500, activation = "relu")
    y_pred_hidden = predictWithHidden(X_test, W1, b1, W2, b2, activation = "relu")
    acc_with_hidden = accuracy_score(y_test, y_pred_hidden)

    # Display Results
    print(f"\nDataset: {name}")
    print(f"Accuracy without  Hidden Layer: {acc_no_hidden * 100:.2f}%")
    print(f"Accuracy with Hidden Layer: {acc_with_hidden * 100:.2f}%\n")

    # Plot Decision Boundaries side by side
    xx, yy = np.meshgrid(np.linspace(X[:, 0].min() - 1, X[:, 0].max() + 1, 100),
                         np.linspace(X[:, 1].min() - 1, X[:, 1].max() + 1, 100))
    grid = np.c_[xx.ravel(), yy.ravel()]

    fig, axes = plt.subplots(1, 2, figsize = (12, 5))

    # Decision Boundary for No Hidden Layer
    zz_no_hidden = predict(grid, weights, bias).reshape(xx.shape)
    axes[0].contourf(xx, yy, zz_no_hidden, alpha = 0.5, cmap = "coolwarm")
    axes[0].scatter(X[:, 0], X[:, 1], c = y, edgecolor = "k", cmap = "coolwarm")
    axes[0].set_title(f"{name} Dataset - No Hidden Layer\nAccuracy: {acc_no_hidden * 100:.2f}%")

    # Decision Boundary for Hidden Layer
    zz_hidden = predictWithHidden(grid, W1, b1, W2, b2, activation = "relu").reshape(xx.shape)
    axes[1].contourf(xx, yy, zz_hidden, alpha = 0.5, cmap = "coolwarm")
    axes[1].scatter(X[:, 0], X[:, 1], c = y, edgecolor = "k", cmap = "coolwarm")
    axes[1].set_title(f"{name} Dataset - With Hidden Layer\nAccuracy: {acc_with_hidden * 100:.2f}%")

    # Adjust layout and display
    plt.tight_layout()
    plt.show()
# Out:
# With No Hidden Layer
# Epoch 0, Training Loss: 0.3429
# Epoch 100, Training Loss: 0.0592
# Epoch 200, Training Loss: 0.0402
# Epoch 300, Training Loss: 0.0325
# Epoch 400, Training Loss: 0.0281
# Epoch 500, Training Loss: 0.0252
# Epoch 600, Training Loss: 0.0231
# Epoch 700, Training Loss: 0.0216
# Epoch 800, Training Loss: 0.0203
# Epoch 900, Training Loss: 0.0193
# Epoch 999, Training Loss: 0.0185
#
# Hidden Layer
# Epoch 0, Training Loss: 0.6963, Accuracy: 0.6457
# Epoch 100, Training Loss: 0.0599, Accuracy: 0.9971
# Epoch 200, Training Loss: 0.0219, Accuracy: 0.9971
# Epoch 300, Training Loss: 0.0159, Accuracy: 0.9971
# Epoch 400, Training Loss: 0.0134, Accuracy: 0.9971
# Epoch 500, Training Loss: 0.0120, Accuracy: 0.9971
# Epoch 600, Training Loss: 0.0111, Accuracy: 0.9971
# Epoch 700, Training Loss: 0.0105, Accuracy: 0.9971
# Epoch 800, Training Loss: 0.0100, Accuracy: 0.9971
# Epoch 900, Training Loss: 0.0096, Accuracy: 0.9971
# Epoch 1000, Training Loss: 0.0093, Accuracy: 0.9971
# Epoch 1100, Training Loss: 0.0091, Accuracy: 0.9971
# Epoch 1200, Training Loss: 0.0089, Accuracy: 0.9971
# Epoch 1300, Training Loss: 0.0087, Accuracy: 0.9971
# Epoch 1400, Training Loss: 0.0086, Accuracy: 0.9971
# Epoch 1500, Training Loss: 0.0084, Accuracy: 0.9971
# Epoch 1600, Training Loss: 0.0083, Accuracy: 0.9971
# Epoch 1700, Training Loss: 0.0082, Accuracy: 0.9971
# Epoch 1800, Training Loss: 0.0081, Accuracy: 0.9971
# Epoch 1900, Training Loss: 0.0080, Accuracy: 0.9971
# Epoch 2000, Training Loss: 0.0079, Accuracy: 0.9971
# Epoch 2100, Training Loss: 0.0078, Accuracy: 0.9971
# Epoch 2200, Training Loss: 0.0078, Accuracy: 0.9971
# Epoch 2300, Training Loss: 0.0077, Accuracy: 0.9971
# Epoch 2400, Training Loss: 0.0076, Accuracy: 0.9971
# Epoch 2500, Training Loss: 0.0076, Accuracy: 0.9971
# Epoch 2600, Training Loss: 0.0075, Accuracy: 0.9971
# Epoch 2700, Training Loss: 0.0075, Accuracy: 0.9971
# Epoch 2800, Training Loss: 0.0074, Accuracy: 0.9971
# Epoch 2900, Training Loss: 0.0074, Accuracy: 0.9971
# Epoch 3000, Training Loss: 0.0073, Accuracy: 0.9971
# Epoch 3100, Training Loss: 0.0073, Accuracy: 0.9971
# Epoch 3200, Training Loss: 0.0073, Accuracy: 0.9971
# Epoch 3300, Training Loss: 0.0072, Accuracy: 0.9971
# Epoch 3400, Training Loss: 0.0072, Accuracy: 0.9971
# Epoch 3500, Training Loss: 0.0072, Accuracy: 0.9971
# Epoch 3600, Training Loss: 0.0071, Accuracy: 0.9971
# Epoch 3700, Training Loss: 0.0071, Accuracy: 0.9971
# Epoch 3800, Training Loss: 0.0070, Accuracy: 0.9971
# Epoch 3900, Training Loss: 0.0070, Accuracy: 0.9971
# Epoch 4000, Training Loss: 0.0070, Accuracy: 0.9971
# Epoch 4100, Training Loss: 0.0070, Accuracy: 0.9971
# Epoch 4200, Training Loss: 0.0069, Accuracy: 0.9971
# Epoch 4300, Training Loss: 0.0069, Accuracy: 0.9971
# Epoch 4400, Training Loss: 0.0069, Accuracy: 0.9971
# Epoch 4499, Training Loss: 0.0068, Accuracy: 0.9971
#
# Dataset: Linear
# Accuracy without  Hidden Layer: 99.67%
# Accuracy with Hidden Layer: 99.67%
# With No Hidden Layer
# Epoch 0, Training Loss: 0.5709
# Epoch 100, Training Loss: 0.3822
# Epoch 200, Training Loss: 0.3379
# Epoch 300, Training Loss: 0.3165
# Epoch 400, Training Loss: 0.3032
# Epoch 500, Training Loss: 0.2942
# Epoch 600, Training Loss: 0.2877
# Epoch 700, Training Loss: 0.2828
# Epoch 800, Training Loss: 0.2792
# Epoch 900, Training Loss: 0.2763
# Epoch 999, Training Loss: 0.2741
#
# Hidden Layer
# Epoch 0, Training Loss: 0.7023, Accuracy: 0.3800
# Epoch 100, Training Loss: 0.5590, Accuracy: 0.8071
# Epoch 200, Training Loss: 0.3962, Accuracy: 0.8286
# Epoch 300, Training Loss: 0.3289, Accuracy: 0.8529
# Epoch 400, Training Loss: 0.2999, Accuracy: 0.8643
# Epoch 500, Training Loss: 0.2856, Accuracy: 0.8714
# Epoch 600, Training Loss: 0.2769, Accuracy: 0.8729
# Epoch 700, Training Loss: 0.2704, Accuracy: 0.8786
# Epoch 800, Training Loss: 0.2651, Accuracy: 0.8786
# Epoch 900, Training Loss: 0.2599, Accuracy: 0.8786
# Epoch 1000, Training Loss: 0.2548, Accuracy: 0.8857
# Epoch 1100, Training Loss: 0.2494, Accuracy: 0.8857
# Epoch 1200, Training Loss: 0.2438, Accuracy: 0.8914
# Epoch 1300, Training Loss: 0.2379, Accuracy: 0.8957
# Epoch 1400, Training Loss: 0.2317, Accuracy: 0.9000
# Epoch 1500, Training Loss: 0.2250, Accuracy: 0.9029
# Epoch 1600, Training Loss: 0.2175, Accuracy: 0.9043
# Epoch 1700, Training Loss: 0.2090, Accuracy: 0.9086
# Epoch 1800, Training Loss: 0.1993, Accuracy: 0.9157
# Epoch 1900, Training Loss: 0.1884, Accuracy: 0.9186
# Epoch 2000, Training Loss: 0.1767, Accuracy: 0.9229
# Epoch 2100, Training Loss: 0.1644, Accuracy: 0.9343
# Epoch 2200, Training Loss: 0.1514, Accuracy: 0.9386
# Epoch 2300, Training Loss: 0.1349, Accuracy: 0.9443
# Epoch 2400, Training Loss: 0.1143, Accuracy: 0.9614
# Epoch 2500, Training Loss: 0.0989, Accuracy: 0.9729
# Epoch 2600, Training Loss: 0.0868, Accuracy: 0.9786
# Epoch 2700, Training Loss: 0.0775, Accuracy: 0.9843
# Epoch 2800, Training Loss: 0.0701, Accuracy: 0.9871
# Epoch 2900, Training Loss: 0.0641, Accuracy: 0.9886
# Epoch 3000, Training Loss: 0.0590, Accuracy: 0.9900
# Epoch 3100, Training Loss: 0.0546, Accuracy: 0.9914
# Epoch 3200, Training Loss: 0.0510, Accuracy: 0.9914
# Epoch 3300, Training Loss: 0.0477, Accuracy: 0.9914
# Epoch 3400, Training Loss: 0.0448, Accuracy: 0.9929
# Epoch 3500, Training Loss: 0.0423, Accuracy: 0.9929
# Epoch 3600, Training Loss: 0.0401, Accuracy: 0.9929
# Epoch 3700, Training Loss: 0.0382, Accuracy: 0.9929
# Epoch 3800, Training Loss: 0.0364, Accuracy: 0.9929
# Epoch 3900, Training Loss: 0.0349, Accuracy: 0.9943
# Epoch 4000, Training Loss: 0.0334, Accuracy: 0.9943
# Epoch 4100, Training Loss: 0.0321, Accuracy: 0.9943
# Epoch 4200, Training Loss: 0.0309, Accuracy: 0.9943
# Epoch 4300, Training Loss: 0.0298, Accuracy: 0.9943
# Epoch 4400, Training Loss: 0.0288, Accuracy: 0.9943
# Epoch 4499, Training Loss: 0.0279, Accuracy: 0.9957
#
# Dataset: Moons
# Accuracy without  Hidden Layer: 88.67%
# Accuracy with Hidden Layer: 100.00%
# With No Hidden Layer
# Epoch 0, Training Loss: 0.7048
# Epoch 100, Training Loss: 0.6950
# Epoch 200, Training Loss: 0.6931
# Epoch 300, Training Loss: 0.6928
# Epoch 400, Training Loss: 0.6927
# Epoch 500, Training Loss: 0.6927
# Epoch 600, Training Loss: 0.6927
# Epoch 700, Training Loss: 0.6927
# Epoch 800, Training Loss: 0.6927
# Epoch 900, Training Loss: 0.6927
# Epoch 999, Training Loss: 0.6927
#
# Hidden Layer
# Epoch 0, Training Loss: 0.6906, Accuracy: 0.4914
# Epoch 100, Training Loss: 0.6853, Accuracy: 0.6129
# Epoch 200, Training Loss: 0.6772, Accuracy: 0.5871
# Epoch 300, Training Loss: 0.6649, Accuracy: 0.5886
# Epoch 400, Training Loss: 0.6484, Accuracy: 0.6243
# Epoch 500, Training Loss: 0.6257, Accuracy: 0.6757
# Epoch 600, Training Loss: 0.5928, Accuracy: 0.7514
# Epoch 700, Training Loss: 0.5463, Accuracy: 0.8129
# Epoch 800, Training Loss: 0.4829, Accuracy: 0.8900
# Epoch 900, Training Loss: 0.4068, Accuracy: 0.9743
# Epoch 1000, Training Loss: 0.3295, Accuracy: 0.9914
# Epoch 1100, Training Loss: 0.2633, Accuracy: 0.9943
# Epoch 1200, Training Loss: 0.2116, Accuracy: 0.9943
# Epoch 1300, Training Loss: 0.1729, Accuracy: 0.9943
# Epoch 1400, Training Loss: 0.1441, Accuracy: 0.9957
# Epoch 1500, Training Loss: 0.1226, Accuracy: 0.9957
# Epoch 1600, Training Loss: 0.1063, Accuracy: 0.9957
# Epoch 1700, Training Loss: 0.0936, Accuracy: 0.9957
# Epoch 1800, Training Loss: 0.0836, Accuracy: 0.9957
# Epoch 1900, Training Loss: 0.0755, Accuracy: 0.9971
# Epoch 2000, Training Loss: 0.0689, Accuracy: 0.9971
# Epoch 2100, Training Loss: 0.0633, Accuracy: 0.9986
# Epoch 2200, Training Loss: 0.0587, Accuracy: 0.9986
# Epoch 2300, Training Loss: 0.0547, Accuracy: 0.9986
# Epoch 2400, Training Loss: 0.0512, Accuracy: 0.9986
# Epoch 2500, Training Loss: 0.0482, Accuracy: 0.9986
# Epoch 2600, Training Loss: 0.0456, Accuracy: 0.9986
# Epoch 2700, Training Loss: 0.0432, Accuracy: 0.9986
# Epoch 2800, Training Loss: 0.0412, Accuracy: 0.9986
# Epoch 2900, Training Loss: 0.0393, Accuracy: 0.9986
# Epoch 3000, Training Loss: 0.0376, Accuracy: 0.9986
# Epoch 3100, Training Loss: 0.0361, Accuracy: 0.9986
# Epoch 3200, Training Loss: 0.0347, Accuracy: 0.9986
# Epoch 3300, Training Loss: 0.0335, Accuracy: 0.9986
# Epoch 3400, Training Loss: 0.0323, Accuracy: 0.9986
# Epoch 3500, Training Loss: 0.0312, Accuracy: 0.9986
# Epoch 3600, Training Loss: 0.0303, Accuracy: 0.9986
# Epoch 3700, Training Loss: 0.0293, Accuracy: 0.9986
# Epoch 3800, Training Loss: 0.0285, Accuracy: 0.9986
# Epoch 3900, Training Loss: 0.0277, Accuracy: 0.9986
# Epoch 4000, Training Loss: 0.0270, Accuracy: 0.9986
# Epoch 4100, Training Loss: 0.0263, Accuracy: 0.9986
# Epoch 4200, Training Loss: 0.0256, Accuracy: 0.9986
# Epoch 4300, Training Loss: 0.0250, Accuracy: 0.9986
# Epoch 4400, Training Loss: 0.0244, Accuracy: 0.9986
# Epoch 4499, Training Loss: 0.0239, Accuracy: 0.9986
#
# Dataset: Circles
# Accuracy without  Hidden Layer: 55.67%
# Accuracy with Hidden Layer: 98.67%
